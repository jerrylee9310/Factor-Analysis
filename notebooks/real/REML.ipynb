# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
ROOT_PATH = "/data/jerrylee"

# %%
GCTA_PATH = f"{ROOT_PATH}/tools/gcta64"
PHENO_DIR = f"{ROOT_PATH}/data/pheno-residual"
GRM_DIR = f"{ROOT_PATH}/data/UKB/unified-grm-maf001"
OUT_DIR = f"{ROOT_PATH}/data/reml-maf001"
SAMPLE_IDXS = np.arange(100) 
MGRM_DIR = f"{ROOT_PATH}/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR"

# %%
# make MGRM file (AD, FACTOR)
def get_grm_fns(
    grm_types: list,
    grm_dir: str,
    chr_indices: list,
    sample_indices: list,
    ):
    grm_fns = []
    for grm_type in grm_types:
        for chr_idx in chr_indices:
            for sample_idx in sample_indices:
                grm_fns.append(f"{grm_dir}/chr{chr_idx}.sample_{sample_idx}.{grm_type}")
    return grm_fns

def save_mgrm_file(
    grm_fns: list,
    mgrm_fn: str,
    ):
    with open(mgrm_fn, "w") as f:
        for grm_fn in grm_fns:
            f.write(f"{grm_fn}\n")

for subsample_idx in SAMPLE_IDXS:
    for std_type in ["AD", "FACTOR"]:   
        # get grm types
        grm_types = ["add", "dom"]
        if std_type == "FACTOR":
            grm_types = ["het", "hom", "hethom"]
            # grm_types = ["het", "hom"]
            
        # get grm files
        grm_fns = get_grm_fns(
            grm_types=grm_types,
            grm_dir=GRM_DIR,
            chr_indices=["1-22"],
            sample_indices=[subsample_idx],
        )
        
        # save mgrm file
        save_mgrm_file(
            grm_fns=grm_fns,
            mgrm_fn=f"{MGRM_DIR}/chr1-22.sample_{subsample_idx}.{std_type}.mgrm",
        )

# %%
pheno_fns = os.listdir(PHENO_DIR)

# %%
# REML
def get_reml_cmd(
    gcta_path: str,
    mgrm_path: str,
    pheno_fn: str,
    out_path: str,
    thread_num: int = 10,
    no_constrain=False,
):
    cmd = [
        gcta_path,
        "--reml",
        "--mgrm", mgrm_path,
        "--pheno", pheno_fn,
        "--out", out_path,
        "--thread-num", str(thread_num),
    ]
    
    if no_constrain:
        cmd.append("--reml-no-constrain")
        
    return " ".join(cmd)
        
for pheno_fn in pheno_fns:
    pheno_name = pheno_fn.split(".")[0]
    
    if not os.path.exists(f"{OUT_DIR}/{pheno_name}"):
        os.makedirs(f"{OUT_DIR}/{pheno_name}")
        
    for sample_idx in SAMPLE_IDXS:
        for std_type in ["AD", "FACTOR"]:
            
            cmd = get_reml_cmd(
                gcta_path=GCTA_PATH,
                mgrm_path=f"{MGRM_DIR}/chr1-22.sample_{sample_idx}.{std_type}.mgrm",
                pheno_fn=f"{PHENO_DIR}/{pheno_fn}",
                out_path=f"{OUT_DIR}/{pheno_name}/{pheno_name}.sample_{sample_idx}.{std_type}",
                thread_num=30,
                no_constrain=True,
            )
            
            os.system(cmd)
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:04:44 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_14.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_14.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_14.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.het.grm.id].
# 3122 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.het.grm.bin].
# GRM for 3122 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.hom.grm.id].
# 3122 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.hom.grm.bin].
# GRM for 3122 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.hethom.grm.id].
# 3122 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.hethom.grm.bin].
# GRM for 3122 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_14.hethom.grm.bin].
# 3108 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3108 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.279529 0.279447 0.251541 0.279625
# logL: -1626.38
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.396197	0.136918
# V(G2)	0.263276	0.122011
# V(G3)	0.024431	0.206197
# V(e)	0.311484	0.171544
# Vp	0.995388	0.207892
# V(G1)/Vp	0.398033	0.170015
# V(G2)/Vp	0.264496	0.142714
# V(G3)/Vp	0.024544	0.202063
#
# Sum of V(G)/Vp	0.687073	0.168625
#
# Sampling variance/covariance of the estimates of variance components:
# 1.874666e-02	-1.638352e-03	-4.333447e-03	-1.660007e-02
# -1.638352e-03	1.488657e-02	-4.547429e-03	-1.299149e-02
# -4.333447e-03	-4.547429e-03	4.251740e-02	8.931407e-03
# -1.660007e-02	-1.299149e-02	8.931407e-03	2.942737e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_15.FACTOR.hsq].
#
# Analysis finished at 16:05:10 KST on Mon Jul 07 2025
# Overall computational time: 13.59 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:05:10 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_16.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_16.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_16.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.het.grm.id].
# 3195 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.het.grm.bin].
# GRM for 3195 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.hom.grm.id].
# 3195 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.hom.grm.bin].
# GRM for 3195 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.hethom.grm.id].
# 3195 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.hethom.grm.bin].
# GRM for 3195 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_16.hethom.grm.bin].
# 3178 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3178 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.286294 0.286603 0.257607  0.28681
# logL: -1703.46
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-1659.20	0.29585	0.31379	0.26316	0.29502
# 2	-1645.53	0.30265	0.33651	0.26655	0.30035
# 3	-1638.45	0.30738	0.35471	0.26849	0.30360
# 4	-1634.87	0.31059	0.36880	0.26954	0.30545
# 5	-1633.10	0.31274	0.37944	0.27005	0.30641
# 6	-1632.24	0.31417	0.38731	0.27027	0.30685
# 7	-1631.82	0.31714	0.40548	0.27046	0.30729
# 8	-1631.45	0.31687	0.40729	0.26996	0.30624
# 9	-1631.45	0.31683	0.40748	0.26990	0.30610
# 10	-1631.45	0.31682	0.40750	0.26990	0.30609
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.43012 0.34204 0.43248
# logL: -1786.48391
# Running AI-REML algorithm ...
# Iter.	logL	V(G2)	V(G3)	V(e)
# 1	-1661.61	0.44239	0.33657	0.46456
# 2	-1648.08	0.45080	0.33049	0.49048
# 3	-1641.08	0.45638	0.32492	0.51063
# 4	-1637.54	0.46000	0.32037	0.52583
# 5	-1635.80	0.46229	0.31690	0.53704
# 6	-1634.94	0.46372	0.31438	0.54516
# 7	-1634.53	0.46649	0.30881	0.56355
# 8	-1634.16	0.46582	0.30907	0.56467
# 9	-1634.16	0.46575	0.30909	0.56475
# 10	-1634.16	0.46574	0.30909	0.56475
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.316824	0.141128
# V(G2)	0.407497	0.136425
# V(G3)	0.269896	0.213201
# V(e)	0.306089	0.178897
# Vp	1.300306	0.216550
# V(G1)/Vp	0.243654	0.119251
# V(G2)/Vp	0.313386	0.123600
# V(G3)/Vp	0.207563	0.129710
#
# Sum of V(G)/Vp	0.764603	0.135064
#
# Sampling variance/covariance of the estimates of variance components:
# 1.991705e-02	-2.694436e-03	-3.178320e-03	-1.680142e-02
# -2.694436e-03	1.861178e-02	-4.653682e-03	-1.543239e-02
# -3.178320e-03	-4.653682e-03	4.545458e-02	8.213405e-03
# -1.680142e-02	-1.543239e-02	8.213405e-03	3.200412e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_16.FACTOR.hsq].
#
# Analysis finished at 16:05:23 KST on Mon Jul 07 2025
# Overall computational time: 13.18 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:05:23 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_17.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_17.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_17.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.het.grm.id].
# 3047 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.het.grm.bin].
# GRM for 3047 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.hom.grm.id].
# 3047 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.hom.grm.bin].
# GRM for 3047 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.hethom.grm.id].
# 3047 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.hethom.grm.bin].
# GRM for 3047 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_17.hethom.grm.bin].
# 3036 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3036 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.285142 0.285242 0.257463 0.285774
# logL: -1621.74
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-1580.42	0.28125	0.28257	0.35665	0.33684
# 2	-1566.73	0.27670	0.27981	0.44072	0.37885
# 3	-1559.57	0.27245	0.27772	0.50768	0.41137
# 4	-1555.93	0.26895	0.27647	0.55848	0.43538
# 5	-1554.12	0.26625	0.27593	0.59567	0.45249
# 6	-1553.24	0.26427	0.27587	0.62221	0.46439
# 7	-1552.81	0.25974	0.27650	0.68114	0.49016
# 8	-1552.43	0.25943	0.27831	0.68169	0.48918
# 9	-1552.43	0.25931	0.27834	0.68181	0.48928
# 10	-1552.43	0.25930	0.27834	0.68181	0.48927
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.42697 0.34271 0.42989
# logL: -1697.69574
# Running AI-REML algorithm ...
# Iter.	logL	V(G2)	V(G3)	V(e)
# 1	-1582.10	0.40635	0.43380	0.49478
# 2	-1568.32	0.38820	0.50767	0.54744
# 3	-1561.14	0.37415	0.56304	0.58753
# 4	-1557.50	0.36424	0.60205	0.61658
# 5	-1555.70	0.35764	0.62842	0.63694
# 6	-1554.84	0.35339	0.64582	0.65094
# 7	-1554.42	0.34490	0.68166	0.68106
# 8	-1554.05	0.34662	0.67697	0.67978
# 9	-1554.05	0.34624	0.67788	0.68016
# 10	-1554.05	0.34632	0.67770	0.68009
# 11	-1554.05	0.34630	0.67773	0.68010
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.259301	0.147197
# V(G2)	0.278345	0.129152
# V(G3)	0.681814	0.210654
# V(e)	0.489272	0.174633
# Vp	1.708732	0.216842
# V(G1)/Vp	0.151751	0.089274
# V(G2)/Vp	0.162895	0.079027
# V(G3)/Vp	0.399017	0.073269
#
# Sum of V(G)/Vp	0.713664	0.104479
#
# Sampling variance/covariance of the estimates of variance components:
# 2.166685e-02	-3.622284e-03	-2.102952e-03	-1.765641e-02
# -3.622284e-03	1.668034e-02	-1.208101e-03	-1.279090e-02
# -2.102952e-03	-1.208101e-03	4.437528e-02	4.281244e-03
# -1.765641e-02	-1.279090e-02	4.281244e-03	3.049659e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_17.FACTOR.hsq].
#
# Analysis finished at 16:05:35 KST on Mon Jul 07 2025
# Overall computational time: 12.13 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:05:35 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_18.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_18.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_18.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.het.grm.id].
# 3236 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.het.grm.bin].
# GRM for 3236 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.hom.grm.id].
# 3236 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.hom.grm.bin].
# GRM for 3236 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.hethom.grm.id].
# 3236 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.hethom.grm.bin].
# GRM for 3236 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_18.hethom.grm.bin].
# 3229 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3229 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.280764 0.281677 0.252935 0.282493
# logL: -1710.04
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-1663.63	0.21860	0.28394	0.30398	0.38527
# 2	-1647.87	0.16390	0.28489	0.34693	0.47258
# 3	-1639.55	0.11894	0.28521	0.38143	0.54268
# 4	-1635.28	0.08379	0.28525	0.40818	0.59659
# 5	-1633.14	0.05727	0.28520	0.42845	0.63675
# 6	-1632.08	0.03776	0.28513	0.44355	0.66601
# 7	-1631.57	0.02363	0.28507	0.45469	0.68701
# 8	-1631.32	-0.00838	0.28492	0.48053	0.73422
# 9	-1631.09	-0.01076	0.28489	0.48418	0.73693
# 10	-1631.09	-0.01096	0.28488	0.48459	0.73716
# 11	-1631.09	-0.01099	0.28487	0.48463	0.73718
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.263031	0.141712
# V(G2)	0.535517	0.132491
# V(G3)	0.181212	0.214050
# V(e)	0.205308	0.178953
# Vp	1.185068	0.216816
# V(G1)/Vp	0.221954	0.130181
# V(G2)/Vp	0.451887	0.148678
# V(G3)/Vp	0.152913	0.152873
#
# Sum of V(G)/Vp	0.826755	0.147444
#
# Sampling variance/covariance of the estimates of variance components:
# 2.008228e-02	-2.167867e-03	-3.523665e-03	-1.754957e-02
# -2.167867e-03	1.755393e-02	-4.900549e-03	-1.479069e-02
# -3.523665e-03	-4.900549e-03	4.581747e-02	8.697944e-03
# -1.754957e-02	-1.479069e-02	8.697944e-03	3.202415e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_19.FACTOR.hsq].
#
# Analysis finished at 16:06:03 KST on Mon Jul 07 2025
# Overall computational time: 13.21 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:06:03 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_20.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_20.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_20.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.het.grm.id].
# 3120 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.het.grm.bin].
# GRM for 3120 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.hom.grm.id].
# 3120 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.hom.grm.bin].
# GRM for 3120 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.hethom.grm.id].
# 3120 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.hethom.grm.bin].
# GRM for 3120 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_20.hethom.grm.bin].
# 3107 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3107 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.281692 0.281793 0.252565 0.282835
# logL: -1649.56
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-1603.99	0.26025	0.27067	0.22575	0.35868
# 2	-1589.47	0.24004	0.25945	0.20077	0.42379
# 3	-1581.85	0.22260	0.24938	0.17928	0.47669
# 4	-1577.96	0.20846	0.24099	0.16182	0.51786
# 5	-1576.01	0.19751	0.23435	0.14820	0.54889
# 6	-1575.05	0.18927	0.22928	0.13788	0.57172
# 7	-1574.59	0.17010	0.21734	0.11364	0.62401
# 8	-1574.16	0.16821	0.21587	0.11060	0.62788
# 9	-1574.16	0.16811	0.21578	0.11038	0.62806
# 10	-1574.16	0.16810	0.21578	0.11037	0.62807
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.42286 0.33520 0.42731
# logL: -1731.49590
# Running AI-REML algorithm ...
# Iter.	logL	V(G2)	V(G3)	V(e)
# 1	-1605.08	0.38316	0.29790	0.50899
# 2	-1590.44	0.34728	0.26337	0.57762
# 3	-1582.72	0.31730	0.23381	0.63236
# 4	-1578.75	0.29360	0.20992	0.67430
# 5	-1576.76	0.27559	0.19136	0.70547
# 6	-1575.77	0.26227	0.17737	0.72815
# 7	-1575.29	0.23169	0.14465	0.77955
# 8	-1574.85	0.22933	0.14093	0.78243
# 9	-1574.85	0.22923	0.14072	0.78253
# 10	-1574.85	0.22923	0.14071	0.78253
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.168103	0.142694
# V(G2)	0.215777	0.128455
# V(G3)	0.110370	0.215961
# V(e)	0.628071	0.181594
# Vp	1.122322	0.218351
# V(G1)/Vp	0.149782	0.133629
# V(G2)/Vp	0.192259	0.125222
# V(G3)/Vp	0.098341	0.173439
#
# Sum of V(G)/Vp	0.440382	0.175193
#
# Sampling variance/covariance of the estimates of variance components:
# 2.036167e-02	-1.832368e-03	-3.785007e-03	-1.828645e-02
# -1.832368e-03	1.650079e-02	-4.068483e-03	-1.446997e-02
# -3.785007e-03	-4.068483e-03	4.663921e-02	8.041783e-03
# -1.828645e-02	-1.446997e-02	8.041783e-03	3.297625e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_20.FACTOR.hsq].
#
# Analysis finished at 16:06:14 KST on Mon Jul 07 2025
# Overall computational time: 11.76 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:06:14 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_21.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_21.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_21.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.het.grm.id].
# 3135 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.het.grm.bin].
# GRM for 3135 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.hom.grm.id].
# 3135 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.hom.grm.bin].
# GRM for 3135 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.hethom.grm.id].
# 3135 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.hethom.grm.bin].
# GRM for 3135 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_21.hethom.grm.bin].
# 3130 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3130 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.276485 0.276914 0.248788  0.27772
# logL: -1631.42
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.437772	0.141041
# V(G2)	0.286458	0.127471
# V(G3)	0.249855	0.212435
# V(e)	0.257922	0.174461
# Vp	1.232007	0.215587
# V(G1)/Vp	0.355333	0.135263
# V(G2)/Vp	0.232513	0.116343
# V(G3)/Vp	0.202803	0.137241
#
# Sum of V(G)/Vp	0.790649	0.138868
#
# Sampling variance/covariance of the estimates of variance components:
# 1.989248e-02	-2.290561e-03	-3.407662e-03	-1.702232e-02
# -2.290561e-03	1.624884e-02	-4.129311e-03	-1.366435e-02
# -3.407662e-03	-4.129311e-03	4.512866e-02	7.899703e-03
# -1.702232e-02	-1.366435e-02	7.899703e-03	3.043663e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_22.FACTOR.hsq].
#
# Analysis finished at 16:06:40 KST on Mon Jul 07 2025
# Overall computational time: 12.87 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:06:40 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_23.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_23.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_23.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_23.het.grm.id].
# 3165 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_23.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_23.het.grm.bin].
# GRM for 3165 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_23.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_23.hom.grm.id].
# 3165 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_23.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_23.hom.grm.bin].
# ...
# V(G2)	0.424974	0.130871
# V(G3)	0.641324	0.206224
# V(e)	0.310922	0.175584
# Vp	1.627563	0.211859
# V(G1)/Vp	0.153815	0.087929
# V(G2)/Vp	0.261110	0.090784
# V(G3)/Vp	0.394039	0.075997
#
# Sum of V(G)/Vp	0.808964	0.106620
#
# Sampling variance/covariance of the estimates of variance components:
# 1.894985e-02	-2.113690e-03	-1.875145e-03	-1.648458e-02
# -2.113690e-03	1.712711e-02	-3.620596e-03	-1.454287e-02
# -1.875145e-03	-3.620596e-03	4.252834e-02	6.361531e-03
# -1.648458e-02	-1.454287e-02	6.361531e-03	3.082961e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_46.FACTOR.hsq].
#
# Analysis finished at 16:13:57 KST on Mon Jul 07 2025
# Overall computational time: 11.95 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:13:57 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_47.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_47.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_47.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.het.grm.id].
# 3078 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.het.grm.bin].
# GRM for 3078 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.hom.grm.id].
# 3078 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.hom.grm.bin].
# GRM for 3078 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.hethom.grm.id].
# 3078 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.hethom.grm.bin].
# GRM for 3078 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_47.hethom.grm.bin].
# 3071 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3071 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.281397 0.280932 0.253413 0.281674
# logL: -1619.49
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-1577.06	0.30611	0.26812	0.31940	0.31401
# 2	-1563.41	0.32679	0.25607	0.37544	0.33981
# 3	-1556.30	0.34338	0.24583	0.42055	0.35941
# 4	-1552.69	0.35625	0.23769	0.45536	0.37373
# 5	-1550.90	0.36597	0.23151	0.48139	0.38390
# 6	-1550.02	0.37317	0.22698	0.50041	0.39097
# 7	-1549.60	0.38978	0.21669	0.54370	0.40628
# 8	-1549.21	0.39138	0.21627	0.54634	0.40564
# 9	-1549.21	0.39147	0.21626	0.54647	0.40556
# 10	-1549.21	0.39147	0.21626	0.54648	0.40556
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.42141 0.33699 0.42492
# logL: -1700.99429
# Running AI-REML algorithm ...
# Iter.	logL	V(G2)	V(G3)	V(e)
# 1	-1581.22	0.39200	0.39362	0.49773
# 2	-1567.31	0.36516	0.44017	0.55836
# 3	-1560.05	0.34265	0.47653	0.60632
# 4	-1556.35	0.32489	0.50381	0.64279
# 5	-1554.52	0.31144	0.52370	0.66969
# 6	-1553.62	0.30156	0.53788	0.68912
# 7	-1553.18	0.27905	0.56944	0.73283
# 8	-1552.79	0.27782	0.56999	0.73456
# 9	-1552.79	0.27780	0.56995	0.73459
# 10	-1552.79	0.27779	0.56994	0.73459
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.391471	0.148111
# V(G2)	0.216259	0.130197
# V(G3)	0.546483	0.218166
# V(e)	0.405555	0.179894
# Vp	1.559769	0.223337
# V(G1)/Vp	0.250980	0.103315
# V(G2)/Vp	0.138648	0.087593
# V(G3)/Vp	0.350362	0.090226
#
# Sum of V(G)/Vp	0.739990	0.115799
#
# Sampling variance/covariance of the estimates of variance components:
# 2.193687e-02	-2.841997e-03	-2.340916e-03	-1.852682e-02
# -2.841997e-03	1.695127e-02	-2.919551e-03	-1.391664e-02
# -2.340916e-03	-2.919551e-03	4.759620e-02	6.062595e-03
# -1.852682e-02	-1.391664e-02	6.062595e-03	3.236184e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_47.FACTOR.hsq].
#
# Analysis finished at 16:14:09 KST on Mon Jul 07 2025
# Overall computational time: 12.22 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:14:09 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_48.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_48.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_48.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.het.grm.id].
# 3108 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.het.grm.bin].
# GRM for 3108 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.hom.grm.id].
# 3108 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.hom.grm.bin].
# GRM for 3108 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.hethom.grm.id].
# 3108 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.hethom.grm.bin].
# GRM for 3108 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_48.hethom.grm.bin].
# 3099 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3099 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.277804 0.276426 0.248717 0.277354
# logL: -1610.75
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-1567.00	0.35197	0.25981	0.21584	0.26270
# 2	-1552.57	0.41631	0.24459	0.18589	0.24714
# 3	-1544.98	0.46887	0.23182	0.16089	0.23277
# 4	-1541.09	0.50984	0.22174	0.14130	0.22063
# 5	-1539.15	0.54067	0.21413	0.12664	0.21097
# 6	-1538.20	0.56327	0.20855	0.11603	0.20360
# 7	-1537.73	0.61473	0.19586	0.09234	0.18631
# 8	-1537.31	0.61760	0.19527	0.09238	0.18461
# 9	-1537.31	0.61770	0.19526	0.09251	0.18452
# 10	-1537.31	0.61771	0.19526	0.09252	0.18451
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.41651 0.32984 0.42069
# logL: -1702.22890
# Running AI-REML algorithm ...
# Iter.	logL	V(G2)	V(G3)	V(e)
# 1	-1576.01	0.38425	0.28734	0.49433
# 2	-1561.57	0.35476	0.24960	0.55608
# 3	-1553.98	0.32991	0.21856	0.60530
# 4	-1550.09	0.31013	0.19439	0.64302
# 5	-1548.14	0.29500	0.17633	0.67109
# 6	-1547.19	0.28376	0.16322	0.69152
# 7	-1546.72	0.25783	0.13370	0.73789
# 8	-1546.30	0.25561	0.13290	0.74061
# 9	-1546.30	0.25553	0.13292	0.74069
# 10	-1546.30	0.25553	0.13292	0.74069
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.617709	0.148368
# V(G2)	0.195262	0.126088
# V(G3)	0.092517	0.216451
# V(e)	0.184515	0.180134
# Vp	1.090003	0.218751
# V(G1)/Vp	0.566704	0.183378
# V(G2)/Vp	0.179139	0.126575
# V(G3)/Vp	0.084878	0.181672
#
# Sum of V(G)/Vp	0.830721	0.162201
#
# Sampling variance/covariance of the estimates of variance components:
# 2.201305e-02	-2.029774e-03	-3.119041e-03	-1.913356e-02
# -2.029774e-03	1.589830e-02	-4.647182e-03	-1.368976e-02
# -3.119041e-03	-4.647182e-03	4.685102e-02	7.940155e-03
# -1.913356e-02	-1.368976e-02	7.940155e-03	3.244814e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_48.FACTOR.hsq].
#
# Analysis finished at 16:14:21 KST on Mon Jul 07 2025
# Overall computational time: 11.88 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 16:14:21 KST on Mon Jul 07 2025.
# Hostname: h2
#
# Accepted options:
# --reml
# --mgrm /data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_49.FACTOR.mgrm
# --pheno /data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv
# --out /data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_49.FACTOR
# --thread-num 30
# --reml-no-constrain
#
# Note: the program will be running on 30 threads.
#
# Reading phenotypes from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
# Non-missing phenotypes of 313644 individuals are included from [/data/jerrylee/pjt/Factor/data/pheno-residual/Standing_height.tsv].
#
# There are 3 GRM file names specified in the file [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/mgrm_AD_FACTOR/chr1-22.sample_49.FACTOR.mgrm].
# Reading the GRM from the 1th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.het.grm.id].
# 3128 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.het.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.het.grm.bin].
# GRM for 3128 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.het.grm.bin].
# Reading the GRM from the 2th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.hom.grm.id].
# 3128 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.hom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.hom.grm.bin].
# GRM for 3128 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.hom.grm.bin].
# Reading the GRM from the 3th file ...
# Reading IDs of the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.hethom.grm.id].
# 3128 IDs are read from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.hethom.grm.id].
# Reading the GRM from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.hethom.grm.bin].
# GRM for 3128 individuals are included from [/data/jerrylee/pjt/Factor/data/UKB/unified-grm-maf001/chr1-22.sample_49.hethom.grm.bin].
# 3115 individuals are in common in these files.
#
# Performing  REML analysis ... (Note: may take hours depending on sample size).
# 3115 observations, 1 fixed effect(s), and 4 variance component(s)(including residual variance).
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.280425 0.280876 0.252945 0.281122
# logL: -1638.81
# Running AI-REML algorithm ...
# Iter.	logL	V(G1)	V(G2)	V(G3)	V(e)
# 1	-1595.84	0.27329	0.30006	0.31573	0.31314
# 2	-1582.11	0.26570	0.31546	0.36986	0.33958
# 3	-1574.97	0.25870	0.32734	0.41416	0.36048
# 4	-1571.35	0.25277	0.33621	0.44896	0.37645
# 5	-1569.55	0.24804	0.34265	0.47549	0.38834
# 6	-1568.66	0.24439	0.34725	0.49526	0.39705
# 7	-1568.24	0.23572	0.35744	0.54118	0.41695
# 8	-1567.85	0.23447	0.35749	0.54626	0.41868
# 9	-1567.85	0.23437	0.35740	0.54675	0.41886
# 10	-1567.85	0.23436	0.35738	0.54680	0.41889
# Log-likelihood ratio converged.
#
# Calculating the logLikelihood for the reduced model ...
# (variance component 1 is dropped from the model)
# Calculating prior values of variance components by EM-REML ...
# Updated prior values: 0.42065 0.33644 0.42311
# logL: -1716.88166
# Running AI-REML algorithm ...
# Iter.	logL	V(G2)	V(G3)	V(e)
# 1	-1596.78	0.41988	0.38940	0.46771
# 2	-1583.25	0.41686	0.43417	0.50473
# 3	-1576.22	0.41298	0.47021	0.53415
# 4	-1572.66	0.40909	0.49814	0.55675
# 5	-1570.90	0.40562	0.51918	0.57367
# 6	-1570.04	0.40271	0.53471	0.58610
# 7	-1569.62	0.39529	0.57049	0.61464
# 8	-1569.24	0.39318	0.57396	0.61723
# 9	-1569.24	0.39293	0.57429	0.61748
# 10	-1569.24	0.39290	0.57432	0.61751
# Log-likelihood ratio converged.
#
# Summary result of REML analysis:
# Source	Variance	SE
# V(G1)	0.234362	0.142199
# V(G2)	0.357382	0.133921
# V(G3)	0.546802	0.218284
# V(e)	0.418888	0.179737
# Vp	1.557434	0.223343
# V(G1)/Vp	0.150480	0.095454
# V(G2)/Vp	0.229468	0.095684
# V(G3)/Vp	0.351092	0.090322
#
# Sum of V(G)/Vp	0.731040	0.114613
#
# Sampling variance/covariance of the estimates of variance components:
# 2.022043e-02	-2.525741e-03	-2.823262e-03	-1.736589e-02
# -2.525741e-03	1.793474e-02	-3.989513e-03	-1.500600e-02
# -2.823262e-03	-3.989513e-03	4.764772e-02	7.597347e-03
# -1.736589e-02	-1.500600e-02	7.597347e-03	3.230531e-02
#
# Summary result of REML analysis has been saved in the file [/data/jerrylee/pjt/Factor/data/reml-maf001/Standing_height/Standing_height.sample_49.FACTOR.hsq].
#
# Analysis finished at 16:14:34 KST on Mon Jul 07 2025
# Overall computational time: 12.78 sec.
